# %% [markdown]
# # Implement a simple deep neural network (DNN) for solving the polynomial equation $𝑦 = 5𝑥^3 − 10𝑥^2 − 20𝑥 + 10$ with the following specifications:

# %% [markdown]
# ## Import Necessary Modules

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Input, Dense, Activation
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model
from tensorflow.keras import metrics
import tensorflow as tf
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## $𝑦 = 5𝑥^3 − 10𝑥^2 − 20𝑥 + 10$

# %%
def calculate_y(x):
  return (5 * (x**3) - 10 * (x**2) - 20*x + 10)

# %% [markdown]
# ## a) Use three hidden-layers of sizes 32, 64, and 128 to build the DNN model

# %%
def dnn_model():
  input = Input((1,), name='InputLayer')
  hidden_layer1 = Dense(32, activation='relu')(input)
  hidden_layer2 = Dense(64, activation='relu')(hidden_layer1)
  hidden_layer3 = Dense(128, activation='relu')(hidden_layer2)
  output = Dense(1, name='OutputLayer')(hidden_layer3)

  model = Model(input, output, name="DNN_Model")
  return model

# %% [markdown]
# ## a) Display the generated DNN model with the required number of parameters

# %%
model = dnn_model()
model.summary()
# Out:
# Model: "DNN_Model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ InputLayer (InputLayer)              │ (None, 1)                   │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_27 (Dense)                     │ (None, 32)                  │              64 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_28 (Dense)                     │ (None, 64)                  │           2,112 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_29 (Dense)                     │ (None, 128)                 │           8,320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ OutputLayer (Dense)                  │ (None, 1)                   │             129 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 10,625 (41.50 KB)
#  Trainable params: 10,625 (41.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## b) Generate training samples within the range of -20 to +20

# %%
def generate_samples(n):
  x = np.random.uniform(-20, 20, n)
  y = calculate_y(x)
  return x, y

# %% [markdown]
# ## b) Use an appropriate method for normalizing the training data in the range of -1 to +1

# %%
def normalize(values):
  maximum = np.max(values)
  minimum = np.min(values)

  return (2 * (values - minimum) / (maximum - minimum)) - 1

# %% [markdown]
# ## c) Use 5% of the samples as test data and 5% of the samples as validation data and the rest of the data for training the DNN with an appropriate number of epochs.

# %%
n = 5000 # Number of samples
x, y = generate_samples(n)

# Normalization
x_norm = normalize(x)
y_norm = normalize(y)

# Manual splitting
# Train
#x_train, y_train = x_norm[:int(n * 0.9)], y_norm[:int(n * 0.9)]
# Validation
#x_val, y_val = x_norm[int(n * 0.9) : int(n * 0.95)], y_norm[int(n * 0.9) : int(n * 0.95)]
# Test
#x_test, y_test = x_norm[int(n * 0.95):], y_norm[int(n * 0.95):]

# Splitting using library function
# Splitting data into train_validation (95%) and test (5%)
x_train_val, x_test, y_train_val, y_test = train_test_split(x_norm, y_norm, test_size=0.05, random_state=42)

# Splitting train_validation data in train (90%) and validation (5%)
x_train, x_val, y_train, y_val = train_test_split(x_train_val, y_train_val, test_size=0.0526, random_state=42)

# %% [markdown]
# ## c) Training

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3), loss='mean_squared_error', metrics=[metrics.R2Score(name='accuracy')])
fitted_model = model.fit(x_train, y_train, epochs=10, validation_data=(x_val, y_val))
history = fitted_model.history
# Out:
# Epoch 1/10
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7538 - loss: 0.0332 - val_accuracy: 0.9858 - val_loss: 0.0020
# Epoch 2/10
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9923 - loss: 0.0011 - val_accuracy: 0.9983 - val_loss: 2.3815e-04
# Epoch 3/10
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9989 - loss: 1.5856e-04 - val_accuracy: 0.9995 - val_loss: 6.5822e-05
# Epoch 4/10
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9995 - loss: 6.2415e-05 - val_accuracy: 0.9998 - val_loss: 2.7792e-05
# Epoch 5/10
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9998 - loss: 2.3259e-05 - val_accuracy: 0.9999 - val_loss: 1.8270e-05
# Epoch 6/10
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9998 - loss: 2.1473e-05 - val_accuracy: 0.9999 - val_loss: 1.2014e-05
# Epoch 7/10
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9999 - loss: 1.0904e-05 - val_accuracy: 0.9999 - val_loss: 1.2265e-05
# Epoch 8/10
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9999 - loss: 8.6419e-06 - val_accuracy: 1.0000 - val_loss: 4.8816e-06
# Epoch 9/10
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 1.0000 - loss: 5.8248e-06 - val_accuracy: 1.0000 - val_loss: 4.1290e-06
# Epoch 10/10
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 4.7666e-06 - val_accuracy: 1.0000 - val_loss: 4.1986e-06

# %% [markdown]
# ## d) Display the training accuracy vs validation accuracy and training error vs validation error curves

# %%
plt.figure(figsize=(14,8))

# Plot Training and Validation Accuracy
plt.subplot(2,2,1)
plt.plot(history['accuracy'])
plt.plot(history['val_accuracy'])
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Training_accuracy', 'Validation_accuracy'])

# Plot Training and Validation Loss
plt.subplot(2,2,2)
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validaton Loss'])

# Evaluate the Model
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)

# Predict on test data
predictions = model.predict(x_test)

# Plot prediction accuracy vs ground truth
plt.subplot(2,2,3)
plt.scatter(x_test,y_test, marker='o')
plt.scatter(x_test, predictions, marker='+')
plt.ylabel('y')
plt.xlabel('x')
plt.legend(['Prediction Accuracy', 'Ground Truth'])

plt.tight_layout()
plt.show()
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 3.0295e-06
# Test Loss: 3.445678885327652e-06
# Test Accuracy: 0.9999728798866272
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
